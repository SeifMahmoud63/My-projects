# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"D:\Airline Project\Airline Dataset Updated - v2.csv")

# %%
df.head()
# Out:
#   Passenger ID First Name Last Name  Gender  Age Nationality  \
# 0       ABVWIg     Edithe    Leggis  Female   62       Japan
# 1       jkXXAX     Elwood      Catt    Male   62   Nicaragua
# 2       CdUz2g      Darby   Felgate    Male   67      Russia
# 3       BRS38V   Dominica      Pyle  Female   71       China
# 4       9kvTLo        Bay   Pencost    Male   21       China
#
#                 Airport Name Airport Country Code   Country Name  \
# 0           Coldfoot Airport                   US  United States
# 1          Kugluktuk Airport                   CA         Canada
# 2     Grenoble-Isère Airport                   FR         France
# 3  Ottawa / Gatineau Airport                   CA         Canada
# 4            Gillespie Field                   US  United States
#
#   Airport Continent     Continents Departure Date Arrival Airport  \
# 0               NAM  North America      6/28/2022             CXF
# 1               NAM  North America     12/26/2022             YCO
# ...

# %%
df.shape
# Out:
# (98619, 15)

# %%
df.isnull().sum()
# Out:
# Passenger ID            0
# First Name              0
# Last Name               0
# Gender                  0
# Age                     0
# Nationality             0
# Airport Name            0
# Airport Country Code    0
# Country Name            0
# Airport Continent       0
# Continents              0
# Departure Date          0
# Arrival Airport         0
# Pilot Name              0
# Flight Status           0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Passenger ID, First Name, Last Name, Gender, Age, Nationality, Airport Name, Airport Country Code, Country Name, Airport Continent, Continents, Departure Date, Arrival Airport, Pilot Name, Flight Status]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98619 entries, 0 to 98618
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Passenger ID          98619 non-null  object
#  1   First Name            98619 non-null  object
#  2   Last Name             98619 non-null  object
#  3   Gender                98619 non-null  object
#  4   Age                   98619 non-null  int64
#  5   Nationality           98619 non-null  object
#  6   Airport Name          98619 non-null  object
#  7   Airport Country Code  98619 non-null  object
#  8   Country Name          98619 non-null  object
#  9   Airport Continent     98619 non-null  object
#  10  Continents            98619 non-null  object
#  11  Departure Date        98619 non-null  object
#  12  Arrival Airport       98619 non-null  object
#  13  Pilot Name            98619 non-null  object
#  14  Flight Status         98619 non-null  object
# ...

# %%
df.describe()
# Out:
#                 Age
# count  98619.000000
# mean      45.504021
# std       25.929849
# min        1.000000
# 25%       23.000000
# 50%       46.000000
# 75%       68.000000
# max       90.000000

# %%
df.head()
# Out:
#   Passenger ID First Name Last Name  Gender  Age Nationality  \
# 0       ABVWIg     Edithe    Leggis  Female   62       Japan
# 1       jkXXAX     Elwood      Catt    Male   62   Nicaragua
# 2       CdUz2g      Darby   Felgate    Male   67      Russia
# 3       BRS38V   Dominica      Pyle  Female   71       China
# 4       9kvTLo        Bay   Pencost    Male   21       China
#
#                 Airport Name Airport Country Code   Country Name  \
# 0           Coldfoot Airport                   US  United States
# 1          Kugluktuk Airport                   CA         Canada
# 2     Grenoble-Isère Airport                   FR         France
# 3  Ottawa / Gatineau Airport                   CA         Canada
# 4            Gillespie Field                   US  United States
#
#   Airport Continent     Continents Departure Date Arrival Airport  \
# 0               NAM  North America      6/28/2022             CXF
# 1               NAM  North America     12/26/2022             YCO
# ...

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      49598
# Female    49021
# Name: count, dtype: int64

# %%
df['Nationality'].value_counts()
# Out:
# Nationality
# China                          18317
# Indonesia                      10559
# Russia                          5693
# Philippines                     5239
# Brazil                          3791
#                                ...
# French Southern Territories        2
# Saint Martin                       2
# Norfolk Island                     1
# Jersey                             1
# Sint Maarten                       1
# Name: count, Length: 240, dtype: int64

# %%
df['Nationality'].nunique()
# Out:
# 240

# %%
for col in df.columns:
    if df[col].dtype == 'object':
        df[col] = df[col].str.strip()

# %%
sns.countplot(x=df['Flight Status']) 
plt.xticks(rotation=45)  
plt.tight_layout()  
plt.show()

# %%
df['Flight Status'].value_counts()
# Out:
# Flight Status
# Cancelled    32942
# On Time      32846
# Delayed      32831
# Name: count, dtype: int64

# %%
sns.histplot(df['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
df.head(2)
# Out:
#   Passenger ID First Name Last Name  Gender  Age Nationality  \
# 0       ABVWIg     Edithe    Leggis  Female   62       Japan
# 1       jkXXAX     Elwood      Catt    Male   62   Nicaragua
#
#         Airport Name Airport Country Code   Country Name Airport Continent  \
# 0   Coldfoot Airport                   US  United States               NAM
# 1  Kugluktuk Airport                   CA         Canada               NAM
#
#       Continents Departure Date Arrival Airport           Pilot Name  \
# 0  North America      6/28/2022             CXF  Fransisco Hazeldine
# 1  North America     12/26/2022             YCO      Marla Parsonage
#
#   Flight Status
# 0       On Time
# 1       On Time

# %%
df['Departure Date'] = pd.to_datetime(df['Departure Date'])

# %%
#Departure Date
df['month']=pd.to_datetime(df['Departure Date']).dt.month
df['day']=pd.to_datetime(df['Departure Date']).dt.day
df['year']=pd.to_datetime(df['Departure Date']).dt.year

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98619 entries, 0 to 98618
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Passenger ID          98619 non-null  object
#  1   First Name            98619 non-null  object
#  2   Last Name             98619 non-null  object
#  3   Gender                98619 non-null  object
#  4   Age                   98619 non-null  int64
#  5   Nationality           98619 non-null  object
#  6   Airport Name          98619 non-null  object
#  7   Airport Country Code  98619 non-null  object
#  8   Country Name          98619 non-null  object
#  9   Airport Continent     98619 non-null  object
#  10  Continents            98619 non-null  object
#  11  Departure Date        98619 non-null  datetime64[s]
#  12  Arrival Airport       98619 non-null  object
#  13  Pilot Name            98619 non-null  object
# ...

# %%
df.head()
# Out:
#   Passenger ID First Name Last Name  Gender  Age Nationality  \
# 0       ABVWIg     Edithe    Leggis  Female   62       Japan
# 1       jkXXAX     Elwood      Catt    Male   62   Nicaragua
# 2       CdUz2g      Darby   Felgate    Male   67      Russia
# 3       BRS38V   Dominica      Pyle  Female   71       China
# 4       9kvTLo        Bay   Pencost    Male   21       China
#
#                 Airport Name Airport Country Code   Country Name  \
# 0           Coldfoot Airport                   US  United States
# 1          Kugluktuk Airport                   CA         Canada
# 2     Grenoble-Isère Airport                   FR         France
# 3  Ottawa / Gatineau Airport                   CA         Canada
# 4            Gillespie Field                   US  United States
#
#   Airport Continent     Continents Departure Date Arrival Airport  \
# 0               NAM  North America     2022-06-28             CXF
# 1               NAM  North America     2022-12-26             YCO
# ...

# %%
df['year'].value_counts()
# Out:
# year
# 2022    98619
# Name: count, dtype: int64

# %%
monthh=df['month'].value_counts()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x=df['month'],y=monthh)
# Out:
# <Axes: xlabel='month', ylabel='count'>

# %%
df['Continents'].value_counts()
# Out:
# Continents
# North America    32033
# Asia             18637
# Oceania          13866
# Europe           12335
# Africa           11030
# South America    10718
# Name: count, dtype: int64

# %%
sns.countplot(x=df['Continents'],hue=df['Gender'])
# Out:
# <Axes: xlabel='Continents', ylabel='count'>

# %%
df['Country Name'].value_counts()
# Out:
# Country Name
# United States       22104
# Australia            6370
# Canada               5424
# Brazil               4504
# Papua New Guinea     4081
#                     ...
# Nauru                   7
# Monaco                  7
# Andorra                 7
# Palau                   5
# Jersey                  4
# Name: count, Length: 235, dtype: int64

# %%
df['Country Name'].nunique()
# Out:
# 235

# %%
df['Pilot Name'].value_counts()
# Out:
# Pilot Name
# Valeda Pratty      2
# Byrle Schooling    2
# Kimmie Godding     2
# Ethan Desbrow      2
# Gustaf Yemm        2
#                   ..
# Goldy Murrish      1
# Arne Yanyushkin    1
# Linc Kydde         1
# Tiffie Nudd        1
# Inglis Dolley      1
# Name: count, Length: 98605, dtype: int64

# %%
df['Pilot Name'].nunique()
# Out:
# 98605

# %%
df.head()
# Out:
#   Passenger ID First Name Last Name  Gender  Age Nationality  \
# 0       ABVWIg     Edithe    Leggis  Female   62       Japan
# 1       jkXXAX     Elwood      Catt    Male   62   Nicaragua
# 2       CdUz2g      Darby   Felgate    Male   67      Russia
# 3       BRS38V   Dominica      Pyle  Female   71       China
# 4       9kvTLo        Bay   Pencost    Male   21       China
#
#                 Airport Name Airport Country Code   Country Name  \
# 0           Coldfoot Airport                   US  United States
# 1          Kugluktuk Airport                   CA         Canada
# 2     Grenoble-Isère Airport                   FR         France
# 3  Ottawa / Gatineau Airport                   CA         Canada
# 4            Gillespie Field                   US  United States
#
#   Airport Continent     Continents Departure Date Arrival Airport  \
# 0               NAM  North America     2022-06-28             CXF
# 1               NAM  North America     2022-12-26             YCO
# ...

# %%
sns.countplot(data=df, x='Continents', hue='Flight Status')
# Out:
# <Axes: xlabel='Continents', ylabel='count'>

# %%
x=df['Airport Name'].value_counts()
x
# Out:
# Airport Name
# San Pedro Airport       43
# Santa Maria Airport     38
# Böblingen Flugfeld      36
# Santa Ana Airport       35
# San Fernando Airport    31
#                         ..
# San Luis Airport         2
# Camaxilo Airport         2
# J F Mitchell Airport     2
# Falcon State Airport     1
# Hiroshima Airport        1
# Name: count, Length: 9062, dtype: int64

# %%
df.query("`Airport Name` =='San Pedro Airport'")
# Out:
#       Passenger ID First Name    Last Name  Gender  Age     Nationality  \
# 1841        FZxEcX      Cozmo      Coneley    Male   67         Uruguay
# 2783        cIfNs9     Haydon        Byham    Male   50         Estonia
# 4572        N23DOi     Randee       Vertey  Female   20           Japan
# 7533        0yl4WE    Sawyere      Whapham    Male   40           China
# 8694        JYnX2M     Blisse     McGraith  Female   30           China
# 9020        ub82oN      Sayer    Enticknap    Male   49  Czech Republic
# 9527        mMgw5I    Shantee       Kiehne  Female   79        Colombia
# 11844       w3u5n5       Augy       Semken    Male    2          Russia
# 14583       0BEJEj        Val    Rowbotham    Male    9        Portugal
# 16431       HkzoQa      Marti        Dyble  Female    5       Indonesia
# 16683       0Q3Dr9     Brandy      Curling  Female   59           China
# 19384       BX8TEX  Kara-lynn     Gheraldi  Female   14          Russia
# ...

# %%
df['Nationality'].value_counts()
# Out:
# Nationality
# China                          18317
# Indonesia                      10559
# Russia                          5693
# Philippines                     5239
# Brazil                          3791
#                                ...
# French Southern Territories        2
# Saint Martin                       2
# Norfolk Island                     1
# Jersey                             1
# Sint Maarten                       1
# Name: count, Length: 240, dtype: int64

# %%
df_grouped = df.groupby('Nationality')['Age'].mean().reset_index(name="NEW C")
df_grouped_sorted = df_grouped.sort_values(by="NEW C", ascending=False)
df_grouped_sorted.head()
# Out:
#                      Nationality      NEW C
# 68              Falkland Islands  80.333333
# 106                       Jersey  73.000000
# 123                        Macao  69.000000
# 75   French Southern Territories  67.500000
# 193                    Singapore  67.333333

# %%
df_grouped_sorted.tail()
# Out:
#                                       Nationality  NEW C
# 176                                       Romania   26.0
# 23                                        Bermuda   25.0
# 200  South Georgia and the South Sandwich Islands   23.0
# 30                         British Virgin Islands   20.0
# 179                                  Saint Helena    4.5
