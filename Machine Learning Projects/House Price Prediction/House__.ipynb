# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\test\Desktop")

# %%
df.shape
# Out:
# (21613, 21)

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    floors  waterfront  view  condition  ...  yr_built  yr_renovated  zipcode  \
# 0     1.0           0     0          3  ...      1955             0    98178
# 1     2.0           0     0          3  ...      1951          1991    98125
# 2     1.0           0     0          3  ...      1933             0    98028
# 3     1.0           0     0          5  ...      1965             0    98136
# 4     1.0           0     0          3  ...      1987             0    98074
#
# ...

# %%
pd.set_option("display.max_columns",None)

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    floors  waterfront  view  condition  grade  yr_built  yr_renovated  \
# 0     1.0           0     0          3      7      1955             0
# 1     2.0           0     0          3      7      1951          1991
# 2     1.0           0     0          3      6      1933             0
# 3     1.0           0     0          5      7      1965             0
# 4     1.0           0     0          3      8      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15  sqft_lot  sqft_above  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   floors         21613 non-null  float64
#  7   waterfront     21613 non-null  int64
#  8   view           21613 non-null  int64
#  9   condition      21613 non-null  int64
#  10  grade          21613 non-null  int64
#  11  yr_built       21613 non-null  int64
#  12  yr_renovated   21613 non-null  int64
#  13  zipcode        21613 non-null  int64
#  14  lat            21613 non-null  float64
#  15  long           21613 non-null  float64
#  16  sqft_living15  21613 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# sqft_lot         0
# sqft_above       0
# sqft_basement    0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, floors, waterfront, view, condition, grade, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15, sqft_lot, sqft_above, sqft_basement]
# Index: []

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.401822e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.673622e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#              floors    waterfront          view     condition         grade  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       1.494309      0.007542      0.234303      3.409430      7.656873
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'yr_built', 'yr_renovated',
#        'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15', 'sqft_lot',
#        'sqft_above', 'sqft_basement'],
#       dtype='object')

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.histplot(x="price",data=df)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
df.price
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
df['price'] = df['price'].astype(float)  
df['price'] = df['price'].apply(lambda x: int(x))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  int64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   floors         21613 non-null  float64
#  7   waterfront     21613 non-null  int64
#  8   view           21613 non-null  int64
#  9   condition      21613 non-null  int64
#  10  grade          21613 non-null  int64
#  11  yr_built       21613 non-null  int64
#  12  yr_renovated   21613 non-null  int64
#  13  zipcode        21613 non-null  int64
#  14  lat            21613 non-null  float64
#  15  long           21613 non-null  float64
#  16  sqft_living15  21613 non-null  int64
# ...

# %%
df.price
# Out:
# 0        221900
# 1        538000
# 2        180000
# 3        604000
# 4        510000
#           ...
# 21608    360000
# 21609    400000
# 21610    402101
# 21611    400000
# 21612    325000
# Name: price, Length: 21613, dtype: int64

# %%
df.tail()
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 21608   263000018  20140521T000000  360000         3       2.50         1530
# 21609  6600060120  20150223T000000  400000         4       2.50         2310
# 21610  1523300141  20140623T000000  402101         2       0.75         1020
# 21611   291310100  20150116T000000  400000         3       2.50         1600
# 21612  1523300157  20141015T000000  325000         2       0.75         1020
#
#        floors  waterfront  view  condition  grade  yr_built  yr_renovated  \
# 21608     3.0           0     0          3      8      2009             0
# 21609     2.0           0     0          3      8      2014             0
# 21610     2.0           0     0          3      7      2009             0
# 21611     2.0           0     0          3      8      2004             0
# 21612     2.0           0     0          3      7      2008             0
#
# ...

# %%
df['date']=pd.to_datetime(df['date']).dt.date

# %%
df.tail()
# Out:
#                id        date   price  bedrooms  bathrooms  sqft_living  \
# 21608   263000018  2014-05-21  360000         3       2.50         1530
# 21609  6600060120  2015-02-23  400000         4       2.50         2310
# 21610  1523300141  2014-06-23  402101         2       0.75         1020
# 21611   291310100  2015-01-16  400000         3       2.50         1600
# 21612  1523300157  2014-10-15  325000         2       0.75         1020
#
#        floors  waterfront  view  condition  grade  yr_built  yr_renovated  \
# 21608     3.0           0     0          3      8      2009             0
# 21609     2.0           0     0          3      8      2014             0
# 21610     2.0           0     0          3      7      2009             0
# 21611     2.0           0     0          3      8      2004             0
# 21612     2.0           0     0          3      7      2008             0
#
#        zipcode      lat     long  sqft_living15  sqft_lot15  sqft_lot  \
# ...

# %%
df['Month']=pd.to_datetime(df['date']).dt.month

# %%
x=np.linspace(1,12,12)
plt.xticks(x)
sns.lineplot(x="Month",y="price",data=df)
# Out:
# <Axes: xlabel='Month', ylabel='price'>

# %%
df.drop("id",axis=1,inplace=True)

# %%
df.head(2)
# Out:
#          date   price  bedrooms  bathrooms  sqft_living  floors  waterfront  \
# 0  2014-10-13  221900         3       1.00         1180     1.0           0
# 1  2014-12-09  538000         3       2.25         2570     2.0           0
#
#    view  condition  grade  yr_built  yr_renovated  zipcode      lat     long  \
# 0     0          3      7      1955             0    98178  47.5112 -122.257
# 1     0          3      7      1951          1991    98125  47.7210 -122.319
#
#    sqft_living15  sqft_lot15  sqft_lot  sqft_above  sqft_basement  Month
# 0           1340        5650      5650        1180              0     10
# 1           1690        7639      7242        2170            400     12

# %%
sns.scatterplot(x="bedrooms",y="price",data=df)
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
df.query("bedrooms >30")
# Out:
#              date   price  bedrooms  bathrooms  sqft_living  floors  \
# 15870  2014-06-25  640000        33       1.75         1620     1.0
#
#        waterfront  view  condition  grade  yr_built  yr_renovated  zipcode  \
# 15870           0     0          5      7      1947             0    98103
#
#            lat     long  sqft_living15  sqft_lot15  sqft_lot  sqft_above  \
# 15870  47.6878 -122.331           1330        4700      6000        1040
#
#        sqft_basement  Month
# 15870            580      6

# %%
sns.histplot(x="yr_built",data=df)
# Out:
# <Axes: xlabel='yr_built', ylabel='Count'>

# %%
sns.histplot(x="sqft_living",data=df)
# Out:
# <Axes: xlabel='sqft_living', ylabel='Count'>

# %%
df['zipcode'].nunique()
# Out:
# 70

# %%
count=0
for i in df['zipcode']:
    if i == 98103:
        count+=1
print("Count of 98103 as a Zipcode is :",count )
# Out:
# Count of 98103 as a Zipcode is : 602

# %%
lis=df.query("zipcode == 98103")

# %%
lis
# Out:
#              date   price  bedrooms  bathrooms  sqft_living  floors  \
# 17     2014-05-29  485000         4       1.00         1600     1.5
# 111    2015-03-04  570000         3       1.75         1260     1.0
# 116    2014-06-26  518500         3       3.50         1590     3.0
# 128    2014-06-13  822500         5       3.50         2320     2.0
# 149    2014-11-04  511000         3       1.00         1430     1.0
# ...           ...     ...       ...        ...          ...     ...
# 21567  2014-06-18  690000         3       3.25         1540     3.0
# 21574  2014-05-07  610950         3       3.00         1680     3.0
# 21592  2015-04-16  475000         3       2.25         1190     3.0
# 21595  2014-10-31  520000         2       2.25         1530     3.0
# 21608  2014-05-21  360000         3       2.50         1530     3.0
#
#        waterfront  view  condition  grade  yr_built  yr_renovated  zipcode  \
# ...

# %%
sns.scatterplot(x="bedrooms",y="price",data=lis)
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
df=df.query("bedrooms <30")

# %%
df
# Out:
#              date   price  bedrooms  bathrooms  sqft_living  floors  \
# 0      2014-10-13  221900         3       1.00         1180     1.0
# 1      2014-12-09  538000         3       2.25         2570     2.0
# 2      2015-02-25  180000         2       1.00          770     1.0
# 3      2014-12-09  604000         4       3.00         1960     1.0
# 4      2015-02-18  510000         3       2.00         1680     1.0
# ...           ...     ...       ...        ...          ...     ...
# 21608  2014-05-21  360000         3       2.50         1530     3.0
# 21609  2015-02-23  400000         4       2.50         2310     2.0
# 21610  2014-06-23  402101         2       0.75         1020     2.0
# 21611  2015-01-16  400000         3       2.50         1600     2.0
# 21612  2014-10-15  325000         2       0.75         1020     2.0
#
#        waterfront  view  condition  grade  yr_built  yr_renovated  zipcode  \
# ...

# %%
sns.scatterplot(x="bathrooms",y="price",data=df)
# Out:
# <Axes: xlabel='bathrooms', ylabel='price'>

# %%
sns.scatterplot(x="sqft_living",y="price",data=df)
# Out:
# <Axes: xlabel='sqft_living', ylabel='price'>

# %%
df.query("sqft_living > 12000")
# Out:
#              date    price  bedrooms  bathrooms  sqft_living  floors  \
# 7252   2014-10-13  7700000         6        8.0        12050     2.5
# 12777  2014-05-05  2280000         7        8.0        13540     3.0
#
#        waterfront  view  condition  grade  yr_built  yr_renovated  zipcode  \
# 7252            0     3          4     13      1910          1987    98102
# 12777           0     4          3     12      1999             0    98053
#
#            lat     long  sqft_living15  sqft_lot15  sqft_lot  sqft_above  \
# 7252   47.6298 -122.323           3940        8800     27600        8570
# 12777  47.6675 -121.986           4850      217800    307752        9410
#
#        sqft_basement  Month
# 7252            3480     10
# 12777           4130      5

# %%
df.head()
# Out:
#          date   price  bedrooms  bathrooms  sqft_living  floors  waterfront  \
# 0  2014-10-13  221900         3       1.00         1180     1.0           0
# 1  2014-12-09  538000         3       2.25         2570     2.0           0
# 2  2015-02-25  180000         2       1.00          770     1.0           0
# 3  2014-12-09  604000         4       3.00         1960     1.0           0
# 4  2015-02-18  510000         3       2.00         1680     1.0           0
#
#    view  condition  grade  yr_built  yr_renovated  zipcode      lat     long  \
# 0     0          3      7      1955             0    98178  47.5112 -122.257
# 1     0          3      7      1951          1991    98125  47.7210 -122.319
# 2     0          3      6      1933             0    98028  47.7379 -122.233
# 3     0          5      7      1965             0    98136  47.5208 -122.393
# 4     0          3      8      1987             0    98074  47.6168 -122.045
#
# ...

# %%
df['floors'].value_counts()
# Out:
# floors
# 1.0    10679
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: count, dtype: int64

# %%
sns.countplot(x="floors",data=df)
# Out:
# <Axes: xlabel='floors', ylabel='count'>

# %%
df.select_dtypes(include=['int','float']).corr()['price']
# Out:
# price            1.000000
# bedrooms         0.315434
# bathrooms        0.525144
# sqft_living      0.702055
# floors           0.256803
# waterfront       0.266332
# view             0.397352
# condition        0.036366
# grade            0.667476
# yr_built         0.053993
# yr_renovated     0.126445
# zipcode         -0.053174
# lat              0.306914
# long             0.021582
# sqft_living15    0.585399
# sqft_lot15       0.082460
# sqft_lot         0.089658
# sqft_above       0.605589
# sqft_basement    0.323833
# Month           -0.010051
# Name: price, dtype: float64

# %%
x=df[["waterfront","view","condition","grade"]]    
for i in x:
    plt.title(f"This graph is :{i}")
    sns.countplot(x=df[i])
    plt.show()
    print("-------------------------")
# Out:
# -------------------------
# -------------------------
# -------------------------
# -------------------------

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21612 entries, 0 to 21612
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   waterfront  21612 non-null  int64
#  1   view        21612 non-null  int64
#  2   condition   21612 non-null  int64
#  3   grade       21612 non-null  int64
# dtypes: int64(4)
# memory usage: 844.2 KB

# %%
x.columns
# Out:
# Index(['waterfront', 'view', 'condition', 'grade'], dtype='object')

# %%
df.head(1)
# Out:
#          date   price  bedrooms  bathrooms  sqft_living  floors  waterfront  \
# 0  2014-10-13  221900         3        1.0         1180     1.0           0
#
#    view  condition  grade  yr_built  yr_renovated  zipcode      lat     long  \
# 0     0          3      7      1955             0    98178  47.5112 -122.257
#
#    sqft_living15  sqft_lot15  sqft_lot  sqft_above  sqft_basement  Month
# 0           1340        5650      5650        1180              0     10

# %%
df['Year of sell']=pd.to_datetime(df['date']).dt.year

# %%
df.head(2)
# Out:
#          date   price  bedrooms  bathrooms  sqft_living  floors  waterfront  \
# 0  2014-10-13  221900         3       1.00         1180     1.0           0
# 1  2014-12-09  538000         3       2.25         2570     2.0           0
#
#    view  condition  grade  yr_built  yr_renovated  zipcode      lat     long  \
# 0     0          3      7      1955             0    98178  47.5112 -122.257
# 1     0          3      7      1951          1991    98125  47.7210 -122.319
#
#    sqft_living15  sqft_lot15  sqft_lot  sqft_above  sqft_basement  Month  \
# 0           1340        5650      5650        1180              0     10
# 1           1690        7639      7242        2170            400     12
#
#    Year of sell
# 0          2014
# 1          2014

# %%
df['How many years of house to sell']=df["Year of sell"]-df["yr_built"]

# %%
df.head()
# Out:
#          date   price  bedrooms  bathrooms  sqft_living  floors  waterfront  \
# 0  2014-10-13  221900         3       1.00         1180     1.0           0
# 1  2014-12-09  538000         3       2.25         2570     2.0           0
# 2  2015-02-25  180000         2       1.00          770     1.0           0
# 3  2014-12-09  604000         4       3.00         1960     1.0           0
# 4  2015-02-18  510000         3       2.00         1680     1.0           0
#
#    view  condition  grade  yr_built  yr_renovated  zipcode      lat     long  \
# 0     0          3      7      1955             0    98178  47.5112 -122.257
# 1     0          3      7      1951          1991    98125  47.7210 -122.319
# 2     0          3      6      1933             0    98028  47.7379 -122.233
# 3     0          5      7      1965             0    98136  47.5208 -122.393
# 4     0          3      8      1987             0    98074  47.6168 -122.045
#
# ...

# %%
sns.lineplot(x="How many years of house to sell",y="price",data=df)
# Out:
# <Axes: xlabel='How many years of house to sell', ylabel='price'>

# %%
Num=np.arange(60,81,1)
Num
# Out:
# array([60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 72, 73, 74, 75, 76,
#        77, 78, 79, 80])

# %%
b60_80=df.query("`How many years of house to sell` in @Num")
b60_80
# Out:
#              date   price  bedrooms  bathrooms  sqft_living  floors  \
# 1      2014-12-09  538000         3       2.25         2570     2.0
# 11     2014-05-27  468000         2       1.00         1160     1.0
# 20     2014-05-14  385000         4       1.75         1620     1.0
# 25     2014-11-03  233000         3       2.00         1710     1.5
# 28     2014-06-24  438000         3       1.75         1520     1.0
# ...           ...     ...       ...        ...          ...     ...
# 20395  2015-03-02  395000         2       1.00          700     1.0
# 21240  2015-04-20  525000         1       1.50         1030     1.0
# 21343  2014-09-25  332220         3       1.50         2580     1.0
# 21470  2015-01-09  249000         3       1.00         1030     1.0
# 21583  2014-06-10  399950         2       1.00          710     2.0
#
#        waterfront  view  condition  grade  yr_built  yr_renovated  zipcode  \
# ...

# %%
b60_80['zipcode'].nunique()
# Out:
# 69

# %%
sns.histplot(x="sqft_living",data=b60_80)
# Out:
# <Axes: xlabel='sqft_living', ylabel='Count'>

# %%
b60_80['long'].min()
# Out:
# np.float64(-122.512)

# %%
b60_80['long'].max()
# Out:
# np.float64(-121.325)

# %%
b60_80["Year of sell"].value_counts()
# Out:
# Year of sell
# 2014    2219
# 2015    1162
# Name: count, dtype: int64

# %%
df['Year of sell'].value_counts()
# Out:
# Year of sell
# 2014    14632
# 2015     6980
# Name: count, dtype: int64

# %%
b70=df.query("`How many years of house to sell` == 70")

# %%
b70['zipcode'].nunique()
# Out:
# 31

# %%
df.head()
# Out:
#          date   price  bedrooms  bathrooms  sqft_living  floors  waterfront  \
# 0  2014-10-13  221900         3       1.00         1180     1.0           0
# 1  2014-12-09  538000         3       2.25         2570     2.0           0
# 2  2015-02-25  180000         2       1.00          770     1.0           0
# 3  2014-12-09  604000         4       3.00         1960     1.0           0
# 4  2015-02-18  510000         3       2.00         1680     1.0           0
#
#    view  condition  grade  yr_built  yr_renovated  zipcode      lat     long  \
# 0     0          3      7      1955             0    98178  47.5112 -122.257
# 1     0          3      7      1951          1991    98125  47.7210 -122.319
# 2     0          3      6      1933             0    98028  47.7379 -122.233
# 3     0          5      7      1965             0    98136  47.5208 -122.393
# 4     0          3      8      1987             0    98074  47.6168 -122.045
#
# ...

# %%
df['yr_renovated'].nunique()
# Out:
# 70

# %%
sns.histplot(x="yr_renovated",data=df)
# Out:
# <Axes: xlabel='yr_renovated', ylabel='Count'>

# %%
df['yr_renovated'].max()
# Out:
# np.int64(2015)

# %%
df['yr_renovated'].min()
# Out:
# np.int64(0)

# %%
sns.scatterplot(x="yr_renovated",y="price",data=df)
# Out:
# <Axes: xlabel='yr_renovated', ylabel='price'>

# %%
df.select_dtypes(include=['int','float']).corr()['price']
# Out:
# price                              1.000000
# bedrooms                           0.315434
# bathrooms                          0.525144
# sqft_living                        0.702055
# floors                             0.256803
# waterfront                         0.266332
# view                               0.397352
# condition                          0.036366
# grade                              0.667476
# yr_built                           0.053993
# yr_renovated                       0.126445
# zipcode                           -0.053174
# lat                                0.306914
# long                               0.021582
# sqft_living15                      0.585399
# sqft_lot15                         0.082460
# sqft_lot                           0.089658
# sqft_above                         0.605589
# sqft_basement                      0.323833
# Month                             -0.010051
# Year of sell                       0.003563
# ...

# %%
xprec=["bedrooms","bathrooms","sqft_living","floors","waterfront","view","grade","sqft_living15","sqft_above","sqft_basement"]

# %%
df.head(2)
# Out:
#          date   price  bedrooms  bathrooms  sqft_living  floors  waterfront  \
# 0  2014-10-13  221900         3       1.00         1180     1.0           0
# 1  2014-12-09  538000         3       2.25         2570     2.0           0
#
#    view  condition  grade  yr_built  yr_renovated  zipcode      lat     long  \
# 0     0          3      7      1955             0    98178  47.5112 -122.257
# 1     0          3      7      1951          1991    98125  47.7210 -122.319
#
#    sqft_living15  sqft_lot15  sqft_lot  sqft_above  sqft_basement  Month  \
# 0           1340        5650      5650        1180              0     10
# 1           1690        7639      7242        2170            400     12
#
#    Year of sell  How many years of house to sell
# 0          2014                               59
# 1          2014                               63

# %%
li=["sqft_living","sqft_living15","sqft_above","lat","sqft_basement"]
for i in li:
    sns.histplot(x=df[i],data=df)
    plt.show()
    print("------------------------------")
# Out:
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------

# %%
for i in li:
    df[i]=np.log1p(df[i])

# %%
for i in li:
    sns.histplot(x=df[i],data=df)
    plt.show()
    print("------------------------------")
# Out:
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------

# %%
x=df[["bedrooms","bathrooms","sqft_living","floors","waterfront","view","grade","sqft_living15","sqft_above","lat","sqft_basement"]]
y=df['price']

# %%
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,random_state=0,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
xtrain=scaler.fit_transform(xtrain)
xtest=scaler.transform(xtest)

# %%
model=LinearRegression().fit(xtrain,ytrain)
ypred=model.predict(xtest)
accuracy=r2_score(ytest,ypred)
print(accuracy)
# Out:
# 0.6070584364726178

# %%
def eval (xtrain,xtest,ytrain,ytest):
    ypred=model.predict(xtest)
    accuracy=r2_score(ytest,ypred)
    print("accuracy of test",accuracy)
    print("-------------------------------")
    ypredtrain=model.predict(xtrain)
    accuracy=r2_score(ytrain,ypredtrain)
    print("accuracy of train",accuracy)
 # to detect the overfit

# %%
ob=eval(xtrain,xtest,ytrain,ytest)
print(ob)
# no overfit but low accuracy
# Out:
# accuracy of test 0.6070584364726178
# -------------------------------
# accuracy of train 0.6162508456866742
# None

# %%
#------------------------------------------------------------------------------

# %%
from sklearn.ensemble import RandomForestRegressor
x=df[["bedrooms","bathrooms","sqft_living","floors","waterfront","view","grade","sqft_living15","sqft_above","lat","sqft_basement"]]
y=df['price']
xtrain,xtest,ytrain,ytest=train_test_split(x,y,random_state=0,test_size=0.2)
model=RandomForestRegressor(n_estimators=150,max_depth=10,min_samples_leaf=6,min_samples_split=6).fit(xtrain,ytrain)
ob=eval(xtrain,xtest,ytrain,ytest)
print(ob)
# Out:
# accuracy of test 0.8127301028209961
# -------------------------------
# accuracy of train 0.8584643577785619
# None

# %%
#--------------------------------------------------------------------------------

# %%
model.__dict__
# Out:
# {'estimator': DecisionTreeRegressor(),
#  'n_estimators': 150,
#  'estimator_params': ('criterion',
#   'max_depth',
#   'min_samples_split',
#   'min_samples_leaf',
#   'min_weight_fraction_leaf',
#   'max_features',
#   'max_leaf_nodes',
#   'min_impurity_decrease',
#   'random_state',
#   'ccp_alpha',
#   'monotonic_cst'),
#  'bootstrap': True,
#  'oob_score': False,
#  'n_jobs': None,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False,
#  'class_weight': None,
#  'max_samples': None,
#  'criterion': 'squared_error',
#  'max_depth': 10,
#  'min_samples_split': 6,
#  'min_samples_leaf': 6,
#  'min_weight_fraction_leaf': 0.0,
#  'max_features': 1.0,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'ccp_alpha': 0.0,
#  'monotonic_cst': None,
#  'feature_names_in_': array(['bedrooms', 'bathrooms', 'sqft_living', 'floors', 'waterfront',
#         'view', 'grade', 'sqft_living15', 'sqft_above', 'lat',
#         'sqft_basement'], dtype=object),
# ...

# %%
from sklearn.model_selection import GridSearchCV

# %%
#-----------------------------------------------------------------------------------
# from sklearn.model_selection import GridSearchCV

# params = {
#     "n_estimators": [100, 150],
#     "max_depth": [5, 10],
#     "min_samples_split": [6, 7],
#     "min_samples_leaf": [6, 7]
# }

# gcv = GridSearchCV(estimator=model, param_grid=params, cv=5)
# gcv.fit(xtrain, ytrain)
# print(gcv.best_estimator_)

# %%
#--------------------------------------------------------

# %%
x=df[["bedrooms","bathrooms","sqft_living","floors","waterfront","view","grade","sqft_living15","sqft_above","lat","sqft_basement"]]
y=df['price']
xtrain,xtest,ytrain,ytest=train_test_split(x,y,random_state=0,test_size=0.2)
import xgboost as XGB
model =XGB.XGBRegressor(max_depth=1,n_estimators=400).fit(xtrain,ytrain)

ypred=model.predict(xtest)
accuracy=r2_score(ytest,ypred)
print(accuracy)
# Out:
# 0.7726093530654907

# %%
# ob=eval(xtrain,xtest,ytrain,ytest)
obb=eval(*x)
# Out:
# accuracy of test 0.7726093530654907
# -------------------------------
# accuracy of train 0.7890385389328003

# %%
from sklearn.linear_model import Lasso

# %%
x=df[["bedrooms","bathrooms","sqft_living","floors","waterfront","view","grade","sqft_living15","sqft_above","lat","sqft_basement"]]
y=df['price']
xtrain,xtest,ytrain,ytest=train_test_split(x,y,random_state=0,test_size=0.2)
model=Lasso().fit(xtrain,ytrain)

ypred=model.predict(xtest)
accuracy=r2_score(ytest,ypred)
print(accuracy)
# Out:
# 0.6070878140314264

# %%
x=[xtrain,xtest,ytrain,ytest]
ob=eval(*x)
# Out:
# accuracy of test 0.6070878140314264
# -------------------------------
# accuracy of train 0.6162498967990204
